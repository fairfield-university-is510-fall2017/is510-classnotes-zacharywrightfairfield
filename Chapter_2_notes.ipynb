# %% [markdown]
# # Class Notes for Kroenke & Auer Chapter 2

# %%
# Setup: Connect to the Cape Codd Outdoor database
# %load_ext sql
# %sql mysql+pymysql://root:mysql@localhost/cape_codd
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: root@cape_codd'

# %%
# %%sql
# SELECT *
# FROM INVENTORY
# Out:
# 32 rows affected.
# [(100, 100100, 'Std. Scuba Tank, Yellow', 250, 0),
#  (200, 100100, 'Std. Scuba Tank, Yellow', 100, 50),
#  (300, 100100, 'Std. Scuba Tank, Yellow', 100, 0),
#  (400, 100100, 'Std. Scuba Tank, Yellow', 200, 0),
#  (100, 100200, 'Std. Scuba Tank, Magenta', 200, 30),
#  (200, 100200, 'Std. Scuba Tank, Magenta', 75, 75),
#  (300, 100200, 'Std. Scuba Tank, Magenta', 100, 100),
#  (400, 100200, 'Std. Scuba Tank, Magenta', 250, 0),
#  (100, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (200, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (300, 101100, 'Dive Mask, Small Clear', 300, 200),
#  (400, 101100, 'Dive Mask, Small Clear', 450, 0),
#  (100, 101200, 'Dive Mask, Med Clear', 100, 500),
#  (200, 101200, 'Dive Mask, Med Clear', 50, 500),
#  (300, 101200, 'Dive Mask, Med Clear', 475, 0),
#  (400, 101200, 'Dive Mask, Med Clear', 250, 250),
#  (100, 201000, 'Half-dome Tent', 2, 100),
#  (200, 201000, 'Half-dome Tent', 10, 250),
#  (300, 201000, 'Half-dome Tent', 250, 0),
#  (400, 201000, 'Half-dome Tent', 0, 250),
#  (100, 202000, 'Half-dome Tent Vestibule', 10, 250),
#  (200, 202000, 'Half-dome Tent Vestibule', 1, 250),
#  (300, 202000, 'Half-dome Tent Vestibule', 100, 0),
#  (400, 202000, 'Half-dome Tent Vestibule', 0, 200),
#  (100, 301000, 'Light Fly Climbing Harness', 300, 250),
#  (200, 301000, 'Light Fly Climbing Harness', 250, 250),
#  (300, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (100, 302000, 'Locking Carabiner, Oval', 1000, 0),
#  (200, 302000, 'Locking Carabiner, Oval', 1250, 0),
#  (300, 302000, 'Locking Carabiner, Oval', 500, 500),
#  (400, 302000, 'Locking Carabiner, Oval', 0, 1000)]

# %%
# %%sql
# SELECT 1+1;
# Out:
# 1 rows affected.
# [(2,)]

# %%
# %%sql
# SELECT *
# FROM inventory;
# Out:
# 32 rows affected.
# [(100, 100100, 'Std. Scuba Tank, Yellow', 250, 0),
#  (200, 100100, 'Std. Scuba Tank, Yellow', 100, 50),
#  (300, 100100, 'Std. Scuba Tank, Yellow', 100, 0),
#  (400, 100100, 'Std. Scuba Tank, Yellow', 200, 0),
#  (100, 100200, 'Std. Scuba Tank, Magenta', 200, 30),
#  (200, 100200, 'Std. Scuba Tank, Magenta', 75, 75),
#  (300, 100200, 'Std. Scuba Tank, Magenta', 100, 100),
#  (400, 100200, 'Std. Scuba Tank, Magenta', 250, 0),
#  (100, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (200, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (300, 101100, 'Dive Mask, Small Clear', 300, 200),
#  (400, 101100, 'Dive Mask, Small Clear', 450, 0),
#  (100, 101200, 'Dive Mask, Med Clear', 100, 500),
#  (200, 101200, 'Dive Mask, Med Clear', 50, 500),
#  (300, 101200, 'Dive Mask, Med Clear', 475, 0),
#  (400, 101200, 'Dive Mask, Med Clear', 250, 250),
#  (100, 201000, 'Half-dome Tent', 2, 100),
#  (200, 201000, 'Half-dome Tent', 10, 250),
#  (300, 201000, 'Half-dome Tent', 250, 0),
#  (400, 201000, 'Half-dome Tent', 0, 250),
#  (100, 202000, 'Half-dome Tent Vestibule', 10, 250),
#  (200, 202000, 'Half-dome Tent Vestibule', 1, 250),
#  (300, 202000, 'Half-dome Tent Vestibule', 100, 0),
#  (400, 202000, 'Half-dome Tent Vestibule', 0, 200),
#  (100, 301000, 'Light Fly Climbing Harness', 300, 250),
#  (200, 301000, 'Light Fly Climbing Harness', 250, 250),
#  (300, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (100, 302000, 'Locking Carabiner, Oval', 1000, 0),
#  (200, 302000, 'Locking Carabiner, Oval', 1250, 0),
#  (300, 302000, 'Locking Carabiner, Oval', 500, 500),
#  (400, 302000, 'Locking Carabiner, Oval', 0, 1000)]

# %%
# %%sql
# # SQL Query-CH02-01
# SELECT SKU, SKU_Description, Department, Buyer
# FROM SKU_DATA;
# Out:
# 8 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# # SQL Query-CH02-01
# SELECT SKU, Department, Buyer, SKU_Description
# FROM SKU_DATA;
# Out:
# 8 rows affected.
# [(100100, 'Water Sports', 'Pete Hansen', 'Std. Scuba Tank, Yellow'),
#  (100200, 'Water Sports', 'Pete Hansen', 'Std. Scuba Tank, Magenta'),
#  (101100, 'Water Sports', 'Nancy Meyers', 'Dive Mask, Small Clear'),
#  (101200, 'Water Sports', 'Nancy Meyers', 'Dive Mask, Med Clear'),
#  (201000, 'Camping', 'Cindy Lo', 'Half-dome Tent'),
#  (202000, 'Camping', 'Cindy Lo', 'Half-dome Tent Vestibule'),
#  (301000, 'Climbing', 'Jerry Martin', 'Light Fly Climbing Harness'),
#  (302000, 'Climbing', 'Jerry Martin', 'Locking Carabiner, Oval')]

# %%
# %%sql
# SELECT *
# FROM Inventory
# WHERE QuantityOnHand < 10;
# Out:
# 9 rows affected.
# [(100, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (200, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (100, 201000, 'Half-dome Tent', 2, 100),
#  (400, 201000, 'Half-dome Tent', 0, 250),
#  (200, 202000, 'Half-dome Tent Vestibule', 1, 250),
#  (400, 202000, 'Half-dome Tent Vestibule', 0, 200),
#  (300, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 302000, 'Locking Carabiner, Oval', 0, 1000)]

# %%
# %%sql
# SELECT Buyer, Department
# From SKU_dATA;
# Out:
# 8 rows affected.
# [('Pete Hansen', 'Water Sports'),
#  ('Pete Hansen', 'Water Sports'),
#  ('Nancy Meyers', 'Water Sports'),
#  ('Nancy Meyers', 'Water Sports'),
#  ('Cindy Lo', 'Camping'),
#  ('Cindy Lo', 'Camping'),
#  ('Jerry Martin', 'Climbing'),
#  ('Jerry Martin', 'Climbing')]

# %%
# %%sql
# SELECT DISTINCT Buyer, Department
# From SKU_DATA;
# Out:
# 4 rows affected.
# [('Pete Hansen', 'Water Sports'),
#  ('Nancy Meyers', 'Water Sports'),
#  ('Cindy Lo', 'Camping'),
#  ('Jerry Martin', 'Climbing')]

# %%
# %%sql
# SELECT SKU, SKU_Description, Department, Buyer
# FROM SKU_DATA
# ORDER BY SKU DESC;
# Out:
# 8 rows affected.
# [(302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen')]

# %%
# %%sql
# SELECT SKU, SKU_Description, Department, Buyer
# FROM SKU_DATA
# ORDER BY SKU_Description, SKU;
# Out:
# 8 rows affected.
# [(101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen')]

# %%
# %%sql
# CREATE VIEW SKU_TENTS
# AS (SELECT SKU, SKU_Description FROM Inventory WHERE SKU_Description like "%Tent%");
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM SKU_TENTS
# Out:
# 8 rows affected.
# [(201000, 'Half-dome Tent'),
#  (201000, 'Half-dome Tent'),
#  (201000, 'Half-dome Tent'),
#  (201000, 'Half-dome Tent'),
#  (202000, 'Half-dome Tent Vestibule'),
#  (202000, 'Half-dome Tent Vestibule'),
#  (202000, 'Half-dome Tent Vestibule'),
#  (202000, 'Half-dome Tent Vestibule')]

# %%
# %%sql
# SELECT *
# FROM CATALOG_SKU_2014
# WHERE DateOnWebsite = '01-Jan-2014';
# Out:
# 0 rows affected.
# C:\Users\Zachary\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1292, "Incorrect date value: '01-Jan-2014' for column 'DateOnWebsite' at row 1")
#   result = self._query(query)
# []

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE Buyer IN ('Nancy Meyers', 'Cindy Lo', 'Jerry Martin');
# Out:
# 6 rows affected.
# [(101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT *
# FROM ORDER_ITEM
# WHERE ExtendedPrice BETWEEN 100 and 200;
# Out:
# 4 rows affected.
# [(2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (1000, 202000, 1, Decimal('130.00'), Decimal('130.00'))]

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE Buyer LIKE 'N%';
# Out:
# 2 rows affected.
# [(101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers')]

# %%
# %%sql
# SELECT *
# FROM CATALOG_SKU_2015
# WHERE CATALOGPage IS NULL;
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE (SKU > 200000 OR SKU_Description LIKE '%TENT%')
# AND NOT Department = 'Camping';
# Out:
# 2 rows affected.
# [(301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE SKU > 20000;
# Out:
# 8 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE SKU > 20000 OR SKU_Description LIKE '%TENT%';
# Out:
# 8 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT *
# FROM SKU_DATA
# WHERE (SKU > 20000 OR SKU_Description LIKE '%TENT%')
# AND NOT Department = 'Camping';
# Out:
# 6 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT COUNT(SKU)
# FROM SKU_DATA;
# Out:
# 1 rows affected.
# [(8,)]

# %%
# %%sql
# SELECT MAX(SKU)
# FROM SKU_DATA;
# Out:
# 1 rows affected.
# [(302000,)]

# %%
# %%sql
# SELECT COUNT(SKU) AS CountOfSKUs
# FROM SKU_DATA;
# Out:
# 1 rows affected.
# [(8,)]

# %%
# %%sql
# SELECT *
# FROM ORDER_ITEM
# WHERE ExtendedPrice > AVG(ExtendedPrice);
# Out:
# (pymysql.err.ProgrammingError) (1111, 'Invalid use of group function') [SQL: 'SELECT *\nFROM ORDER_ITEM\nWHERE ExtendedPrice > AVG(ExtendedPrice);']

# %%
# %%sql
# SELECT (Quantity * Price) AS EP
# FROM ORDER_ITEM;
# Out:
# 7 rows affected.
# [(Decimal('300.00'),),
#  (Decimal('200.00'),),
#  (Decimal('100.00'),),
#  (Decimal('100.00'),),
#  (Decimal('50.00'),),
#  (Decimal('300.00'),),
#  (Decimal('130.00'),)]

# %%
# %%sql
# SELECT *
# FROM ORDER_ITEM
# WHERE (Quantity * Price) > 150;
# Out:
# 3 rows affected.
# [(3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (1000, 201000, 1, Decimal('300.00'), Decimal('300.00'))]

# %%
# %%sql
# SELECT SKU, COUNT(SKU), AVG(ExtendedPrice)
# FROM ORDER_ITEM
# GROUP BY SKU;
# Out:
# 5 rows affected.
# [(100200, 1, Decimal('300.000000')),
#  (101100, 2, Decimal('150.000000')),
#  (101200, 2, Decimal('75.000000')),
#  (201000, 1, Decimal('300.000000')),
#  (202000, 1, Decimal('130.000000'))]

# %%
# %%sql
# SELECT SKU, SKU_Description, SUM(QuantityOnHand)
# FROM Inventory
# GROUP BY SKU, SKU_Description;
# Out:
# 8 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', Decimal('650')),
#  (100200, 'Std. Scuba Tank, Magenta', Decimal('625')),
#  (101100, 'Dive Mask, Small Clear', Decimal('750')),
#  (101200, 'Dive Mask, Med Clear', Decimal('875')),
#  (201000, 'Half-dome Tent', Decimal('262')),
#  (202000, 'Half-dome Tent Vestibule', Decimal('111')),
#  (301000, 'Light Fly Climbing Harness', Decimal('550')),
#  (302000, 'Locking Carabiner, Oval', Decimal('2750'))]

# %%
# %%sql
# SELECT SKU, SUM(QuantityOnHand) AS QuantOnHand
# FROM Inventory
# GROUP BY SKU
# HAVING QuantOnHand < 1000;
# Out:
# 7 rows affected.
# [(100100, Decimal('650')),
#  (100200, Decimal('625')),
#  (101100, Decimal('750')),
#  (101200, Decimal('875')),
#  (201000, Decimal('262')),
#  (202000, Decimal('111')),
#  (301000, Decimal('550'))]

# %%
# %%sql
# SELECT SKU, SUM(QuantityOnHand) AS QuantOnHand
# FROM Inventory
# GROUP BY SKU
# ORDER BY QuantOnHand ASC;
# Out:
# 8 rows affected.
# [(202000, Decimal('111')),
#  (201000, Decimal('262')),
#  (301000, Decimal('550')),
#  (100200, Decimal('625')),
#  (100100, Decimal('650')),
#  (101100, Decimal('750')),
#  (101200, Decimal('875')),
#  (302000, Decimal('2750'))]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER, ORDER_ITEM
# ORDER BY RETAIL_ORDER.OrderNumber;
# Out:
# 21 rows affected.
# [(1000, 10, '98110', 'December', 2014, Decimal('445.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00'))]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER, ORDER_ITEM
# WHERE RETAIL_ORDER.OrderNumber = ORDER_ITEM.OrderNumber;
# Out:
# 7 rows affected.
# [(3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00'))]

# %%
# %%sql
# SELECT *
# FROM SKU_DATA AS SD1, SKU_DATA AS SD2
# WHERE (SD1.SKU - SD2.SKU) BETWEEN 0 and 1000;
# Out:
# 15 rows affected.
# [(100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen', 100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen', 100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers', 100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen', 100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers', 100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers', 100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers', 101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers', 101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers', 101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo', 201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo', 201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo', 202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin', 301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin', 301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin', 302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER JOIN ORDER_ITEM ON (RETAIL_ORDER.OrderNumber = ORDER_ITEM.OrderNumber);
# Out:
# 7 rows affected.
# [(3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00'))]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER LEFT JOIN ORDER_ITEM ON (RETAIL_ORDER.OrderNumber = ORDER_ITEM.OrderNumber);
# Out:
# 7 rows affected.
# [(3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00'))]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER RIGHT JOIN ORDER_ITEM ON (RETAIL_ORDER.OrderNumber = ORDER_ITEM.OrderNumber);
# Out:
# 7 rows affected.
# [(1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00')),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00'))]

# %%
# %%sql
# SELECT *
# FROM RETAIL_ORDER
# JOIN ORDER_ITEM ON (RETAIL_ORDER.OrderNumber = ORDER_ITEM.OrderNumber)
# JOIN SKU_DATA ON (SKU_DATA.SKU = ORDER_ITEM.SKU);
# Out:
# 7 rows affected.
# [(3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 100200, 1, Decimal('300.00'), Decimal('300.00'), 100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101100, 4, Decimal('50.00'), Decimal('200.00'), 101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101100, 2, Decimal('50.00'), Decimal('100.00'), 101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (2000, 20, '02335', 'December', 2014, Decimal('310.00'), 2000, 101200, 2, Decimal('50.00'), Decimal('100.00'), 101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (3000, 10, '98110', 'January', 2015, Decimal('480.00'), 3000, 101200, 1, Decimal('50.00'), Decimal('50.00'), 101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 201000, 1, Decimal('300.00'), Decimal('300.00'), 201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (1000, 10, '98110', 'December', 2014, Decimal('445.00'), 1000, 202000, 1, Decimal('130.00'), Decimal('130.00'), 202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo')]

# %%
# %%sql
